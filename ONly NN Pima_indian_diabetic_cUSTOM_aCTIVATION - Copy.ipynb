# %%
#importing Library pandas and display the csv file in it
import pandas as pd
df = pd.read_csv("/content/diabetes.csv")
df.head(10).style.background_gradient(cmap = 'gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_00758_row0_col0 {
#   background-color: #00ff00;
#   color: #000000;
# }
# #T_00758_row0_col1 {
#   background-color: #00ff10;
#   color: #000000;
# }
# #T_00758_row0_col2 {
#   background-color: #d3ff00;
#   color: #000000;
# }
# #T_00758_row0_col3, #T_00758_row0_col5, #T_00758_row4_col3 {
#   background-color: #f9ff00;
#   color: #000000;
# }
# #T_00758_row0_col4, #T_00758_row1_col4, #T_00758_row1_col8, #T_00758_row2_col3, #T_00758_row2_col4, #T_00758_row3_col7, #T_00758_row3_col8, #T_00758_row4_col0, #T_00758_row5_col3, #T_00758_row5_col4, #T_00758_row5_col8, #T_00758_row6_col1, #T_00758_row7_col2, #T_00758_row7_col3, #T_00758_row7_col4, #T_00758_row7_col6, #T_00758_row7_col8, #T_00758_row9_col3, #T_00758_row9_col4, #T_00758_row9_col5 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_00758_row0_col6 {
#   background-color: #0400ff;
#   color: #f1f1f1;
# }
# #T_00758_row0_col7 {
#   background-color: #ff7e00;
#   color: #f1f1f1;
# }
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.shape
# Out:
# (768, 9)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.countplot(df['Outcome'])
plt.show()

# %%
plt.plot(fig_size = (12,16))
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
dict={}
for i in df.columns:
    dict[i]=df[i].value_counts().shape[0]
    
pd.DataFrame(dict,index=['Unique']).T.style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_81821_row0_col0 {
#   background-color: #d0efd9;
#   color: #000000;
# }
# #T_81821_row1_col0 {
#   background-color: #47bfad;
#   color: #000000;
# }
# #T_81821_row2_col0 {
#   background-color: #b0e4c1;
#   color: #000000;
# }
# #T_81821_row3_col0, #T_81821_row7_col0 {
#   background-color: #abe2be;
#   color: #000000;
# }
# #T_81821_row4_col0 {
#   background-color: #36a3ab;
#   color: #f1f1f1;
# }
# #T_81821_row5_col0 {
#   background-color: #3480a4;
#   color: #f1f1f1;
# }
# #T_81821_row6_col0 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_81821_row8_col0 {
#   background-color: #def5e5;
#   color: #000000;
# }
# </style>
# <table id="T_81821_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81821_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
# ...

# %%
df.describe().style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_f8892_row0_col0, #T_f8892_row0_col1, #T_f8892_row0_col2, #T_f8892_row0_col3, #T_f8892_row0_col5, #T_f8892_row0_col6, #T_f8892_row0_col7, #T_f8892_row0_col8, #T_f8892_row7_col4 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_f8892_row0_col4 {
#   background-color: #231526;
#   color: #f1f1f1;
# }
# #T_f8892_row1_col0, #T_f8892_row2_col0, #T_f8892_row5_col0 {
#   background-color: #dcf4e3;
#   color: #000000;
# }
# #T_f8892_row1_col1, #T_f8892_row7_col2 {
#   background-color: #7fd7af;
#   color: #000000;
# }
# #T_f8892_row1_col2, #T_f8892_row7_col7 {
#   background-color: #aee3c0;
#   color: #000000;
# }
# #T_f8892_row1_col3, #T_f8892_row2_col2 {
#   background-color: #d2f0db;
#   color: #000000;
# }
# #T_f8892_row1_col4, #T_f8892_row5_col2 {
#   background-color: #abe2be;
#   color: #000000;
# }
# #T_f8892_row1_col5, #T_f8892_row2_col1, #T_f8892_row5_col5, #T_f8892_row6_col3 {
#   background-color: #caedd4;
#   color: #000000;
# }
# ...

# %%
sns.violinplot(x="Outcome", y="Pregnancies", data=df)
plt.show()

# %%
#Plot Histrogram of Pregnancies Features......
import plotly.express as px
fig = px.histogram(df, x="Pregnancies",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.diverging.Tropic)
fig.update_layout(title_text="<b> Distribution Of The Pregnancies Features </b>",
                  title_x=0.5, 
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plot Histrogram of Glucose Features......
fig = px.histogram(df, x="Glucose",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.sequential.gray)

fig.update_layout(title_text="<b> Distribution Of The Glucose Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="BloodPressure",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.diverging.Tropic)

fig.update_layout(title_text="<b> Distribution Of The BloodPressure Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plot Histrogram of SkinThickness Features......
fig = px.histogram(df, x="SkinThickness",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.sequential.gray)

fig.update_layout(title_text="<b> Distribution Of The SkinThickness Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plot Histrogram of Insulin Features......
fig = px.histogram(df, x="Insulin",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.diverging.Tropic)

fig.update_layout(title_text="<b> Distribution Of The Insulin Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plot Histrogram of BMI Features......
fig = px.histogram(df, x="BMI",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.sequential.gray)

fig.update_layout(title_text="<b> Distribution Of The BMI Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plot Histrogram of DiabetesPedigreeFunctionDiabetesPedigreeFunction Features......
fig = px.histogram(df, x="DiabetesPedigreeFunction",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.diverging.Tropic)

fig.update_layout(title_text="<b> Distribution Of The DiabetesPedigreeFunction Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="Age",marginal="box",template ="simple_white",color_discrete_sequence = px.colors.sequential.gray)

fig.update_layout(title_text="<b> Distribution Of The Age Features </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plot Donut chart of Outcome Features......
fig=px.pie(df,values=df['Outcome'].value_counts(),names=df['Outcome'].value_counts().index,template ="simple_white",color_discrete_sequence = px.colors.diverging.Tropic,hole=.6)
fig.update_layout(title_text="<b> Distribution Of The Target Feature-Outcome </b>",
                  title_x=0.5,
                  font_size=15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Outlier Detection

# %%
def z_score_outlier(df):
    out=[] 
    m = np.mean(df)
    sd = np.std(df)
    for i in df: 
        z = (i-m)/sd
        if np.abs(z) > 3: 
            out.append(i)
    print("Outliers:",out)

# %%
z = (0-120.89)/(31.97)
print(z)
# Out:
# -3.7813575226775105

# %%
z_score_outlier(df['Glucose'])
# Out:
# Outliers: [0, 0, 0, 0, 0]

# %%
z_score_outlier(df['DiabetesPedigreeFunction'])
# Out:
# Outliers: [2.288, 1.893, 1.781, 2.329, 1.476, 2.137, 1.731, 1.6, 2.42, 1.699, 1.698]

# %%
df['DiabetesPedigreeFunction'].describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
df[df['DiabetesPedigreeFunction'] >=1.6]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0      137             40             35      168  43.1
# 45             0      180             66             39        0  42.0
# 58             0      146             82              0        0  40.5
# 228            4      197             70             39      744  36.7
# 370            3      173             82             48      465  38.4
# 371            0      118             64             23       89   0.0
# 395            2      127             58             24      275  27.7
# 445            0      180             78             63       14  59.4
# 593            2       82             52             22      115  28.5
# 621            2       92             76             20        0  24.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 4                       2.288   33        1
# 45                      1.893   25        1
# 58                      1.781   44        0
# ...

# %% [markdown]
# ROBUST Z-SCORE
# It is also called as Median absolute deviation method. It is similar to Z-score method with some changes in parameters. Since mean and standard deviations are heavily influenced by outliers, alter to this parameters we use median and absolute deviation from median.

# %%
# !pip install spicy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from scipy.stats import median_absolute_deviation

# %%
def ZRscore_outlier(df):
    out = []
    med = np.median(df)
    ma = median_absolute_deviation(df)
    for i in df: 
        z = (0.6745*(i-med))/ (np.median(ma))
        if np.abs(z) > 3: 
            out.append(i)
    return len(out)

# %%
outliers = []
for column in df.columns:
  outliers.append(ZRscore_outlier(df[str(column)]))

# %%
fig = plt.figure(figsize = (13, 5))
plt.title("Number of outliers")
plt.bar(df.columns, outliers,
        width = 0.5)
plt.show()

# %% [markdown]
# As Insulin has many outliers we can drop it.

# %%
df.drop(['Insulin'], axis=1, inplace=True)
diabetes_data = df[df['DiabetesPedigreeFunction'] < 1.6]

# %% [markdown]
# Splitting of Dataset

# %%
y = diabetes_data['Outcome']
X = diabetes_data.drop(['Outcome'], axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=40)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (568, 7)
# (568,)

# %%
#data Transform
from sklearn.preprocessing import MinMaxScaler
Min_max_scaler = MinMaxScaler().fit(X_train)

## Scaling 
X_train_mm_scaled = Min_max_scaler.transform(X_train)
X_test_mm_scaled = Min_max_scaler.transform(X_test)

## Numpy Array to DataFrame 
df_train_mm_scaled = pd.DataFrame(X_train_mm_scaled)
df_test_mm_scaled = pd.DataFrame(X_test_mm_scaled)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
def get_results(train_x, train_y, test_x, test_y, classifiers): 
    names = []
    accuracy_list = [] 
    precision_list = []
    recall_list = [] 
    f1_list = []
    
    for cls in classifiers: 
        cls.fit(train_x, train_y)
        y_preds = cls.predict(test_x) 
        
        accuracy = round(cls.score(test_x, test_y), 3) 
        precision = round(precision_score(y_test, y_preds), 3)
        recall = round(recall_score(y_test, y_preds), 3)
        f1 = round(f1_score(y_test, y_preds), 3)
        
        names.append(cls.__class__.__name__)
        accuracy_list.append(accuracy)
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)
    
    results = {'Models': names, 
               'Accuracy': accuracy_list, 
               'Precision': precision_list, 
               'Recall': recall_list, 
               'F1': f1_list}
    
    resultsDF = pd.DataFrame.from_dict(results)
    return resultsDF

# %%
def get_results_unsuper(train_x, test_x,classifiers): 
    names = []
    accuracy_list = [] 
    precision_list = []
    recall_list = [] 
    f1_list = []
    
    for cls in classifiers: 
        cls.fit(train_x)
        y_preds = cls.predict(test_x) 
        
        accuracy = round(cls.score(test_x), 3) 
        precision = round(precision_score(y_test, y_preds), 3)
        recall = round(recall_score(y_test, y_preds), 3)
        f1 = round(f1_score(y_test, y_preds), 3)
        
        names.append(cls.__class__.__name__)
        accuracy_list.append(accuracy)
        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)
    
    results = {'Models': names, 
               'Accuracy': accuracy_list, 
               'Precision': precision_list, 
               'Recall': recall_list, 
               'F1': f1_list}
    
    resultsDF = pd.DataFrame.from_dict(results)
    return resultsDF

# %%
from sklearn.svm import SVC

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVR

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X, y = make_regression(n_features=4, n_informative=2, random_state=0, shuffle=False)
rfr = RandomForestRegressor(max_depth=3)

model_nb = GaussianNB(var_smoothing=0.001)
model_lr = LogisticRegression()
model_dt = DecisionTreeClassifier(criterion='entropy', max_depth=3)
model_svc = SVC(kernel="linear")
model_gbc = GradientBoostingClassifier(random_state=42)
from sklearn.neighbors import KNeighborsClassifier
model_neigh = KNeighborsClassifier(n_neighbors=2)
from sklearn.cluster import KMeans
model_kmeans = KMeans(n_clusters=2, random_state=0)

classifiers = [model_nb, model_lr, model_dt, model_svc,model_gbc,model_neigh]

# %%
results = get_results(X_train_mm_scaled, y_train, X_test_mm_scaled, y_test, classifiers)

# %%
clf = [model_kmeans]

# %%
# results1 = get_results_unsuper(X_train_mm_scaled, X_test_mm_scaled, clf)

# %%
results
# Out:
#                        Models  Accuracy  Precision  Recall     F1
# 0                  GaussianNB     0.716      0.597   0.561  0.578
# 1          LogisticRegression     0.753      0.667   0.576  0.618
# 2      DecisionTreeClassifier     0.753      0.661   0.591  0.624
# 3                         SVC     0.763      0.678   0.606  0.640
# 4  GradientBoostingClassifier     0.753      0.651   0.621  0.636
# 5        KNeighborsClassifier     0.689      0.600   0.318  0.416

# %%
# results1

# %%
model_kmeans.fit(X_train_mm_scaled)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
y_test
# Out:
# 145    0
# 758    0
# 539    1
# 435    1
# 454    0
#       ..
# 741    0
# 394    1
# 742    0
# 340    0
# 131    1
# Name: Outcome, Length: 190, dtype: int64

# %%
# from sklearn.metrics import roc_curve
# from sklearn.metrics import auc
# fig = plt.figure(figsize=(15,10))
# for clf in classifiers:
#   y_pred = clf.predict(X_test_mm_scaled)
#   fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred)
#   auc_rf = auc(fpr_rf, tpr_rf)
#   plt.plot([0, 1], [0, 1], 'k--')
#   plt.plot(fpr_rf, tpr_rf, label='(area = {:.3f})'.format(auc_rf))
# y_pred = model_kmeans.predict(X_test_mm_scaled)
# fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred)
# auc_rf = auc(fpr_rf, tpr_rf)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.plot(fpr_rf, tpr_rf, label='(area = {:.3f})'.format(auc_rf))
# y_pred = model.predict(X_test)
# fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred)
# auc_rf = auc(fpr_rf, tpr_rf)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.plot(fpr_rf, tpr_rf, label=' (area = {:.3f})'.format(auc_rf))
# plt.xlabel('False positive rate')
# plt.ylabel('True positive rate')
# plt.title('ROC curve')
# plt.legend(loc='best',prop={'size':12})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5719147c576c> in <module>
#      13 plt.plot([0, 1], [0, 1], 'k--')
#      14 plt.plot(fpr_rf, tpr_rf, label='(area = {:.3f})'.format(auc_rf))
# ---> 15 y_pred = model.predict(X_test)
#      16 fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred)
#      17 auc_rf = auc(fpr_rf, tpr_rf)
#
# NameError: name 'model' is not defined

# %%
# import plotly.express as px

# from sklearn.metrics import auc
# plt.figure(figsize=(10,12))
# for clf in classifiers:
#   y_pred = clf.predict(X_test_mm_scaled)
#   fpr, tpr, thresholds_rf = roc_curve(y_test, y_pred)
#   auc_ = auc(fpr, tpr)
#   fig = px.area(
#     x=fpr, y=tpr,
#     width=700, height=500
#   )
#   fig.add_shape(
#     type='line',
#     x0=0, x1=1, y0=0, y1=1
#   )

#   fig.update_yaxes(scaleanchor="x", scaleratio=1)
#   fig.update_xaxes(constrain='domain')
# y_pred = model_kmeans.predict(X_test_mm_scaled)
# fpr, tpr, thresholds_rf = roc_curve(y_test, y_pred)
# auc_ = auc(fpr, tpr)
# fig = px.area(
#     x=fpr, y=tpr,
#     width=700, height=500
#   )
# fig.add_shape(
#     type='line',
#     x0=0, x1=1, y0=0, y1=1
#   )

# fig.update_yaxes(scaleanchor="x", scaleratio=1)
# fig.update_xaxes(constrain='domain')
# y_pred = model.predict(X_test)
# fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred)
# auc_rf = auc(fpr_rf, tpr_rf)
# fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (568, 7)
# (568,)

# %%
import tensorflow as tf

# %%
# !pip install keras_metrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#how to add custom activation functions to keras
from keras import backend as K
from keras.layers.core import Activation
from keras.utils.generic_utils import get_custom_objects
from keras.layers import LeakyReLU
### Note! You cannot use random python functions, activation function gets as an input tensorflow tensors and should return tensors. There are a lot of helper functions in keras backend.
def custom_activation(x):
  
    return (1/(1 + K.exp(-x)))
     
get_custom_objects().update({'custom_activation': Activation(custom_activation)})


# Add the GELU function to Keras
def gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))
get_custom_objects().update({'gelu': Activation(gelu)})

# Add leaky-relu so we can use it as a string
get_custom_objects().update({'leaky-relu': Activation(LeakyReLU(alpha=0.2))})

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Model 1: Basic Neural Network layers with custom Activation functions 
import tensorflow as tf
import keras_metrics
model = tf.keras.models.Sequential([
       tf.keras.layers.Input(shape =(None,7)),
       tf.keras.layers.Dense(128,activation='relu'),
       tf.keras.layers.Dense(256,activation='softplus'),
       tf.keras.layers.Dense(128,activation='softsign'),
       tf.keras.layers.Dense(56,activation='selu'),
       tf.keras.layers.Dense(32,activation='elu'),
       tf.keras.layers.Dense(28,activation='relu'),
       tf.keras.layers.Dense(21,activation='custom_activation'),
       tf.keras.layers.Dense(21,activation='gelu'),
       tf.keras.layers.Dense(21,activation='leaky-relu'),
       tf.keras.layers.Dense(1,activation='sigmoid')])
model.compile(loss = tf.keras.losses.MeanSquaredError(),optimizer = 'adam',metrics = ['accuracy'])
history =model.fit(X_train,y_train,validation_data = (X_test,y_test),epochs = 300)
# Out:
# Epoch 1/300
# WARNING:tensorflow:Model was constructed with shape (None, None, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 7), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 7).
# WARNING:tensorflow:Model was constructed with shape (None, None, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 7), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 7).
# 11/18 [=================>............] - ETA: 0s - loss: 0.2274 - accuracy: 0.6534
# WARNING:tensorflow:Model was constructed with shape (None, None, 7) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 7), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 7).
# ...

# %%
#Model 2: MLP Model
def build_model():
  model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),                  
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(1)
  ], name="MLP_model")

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss=tf.keras.losses.MeanSquaredError(),
                optimizer='adam',
                metrics=['accuracy'])
  return model

model = build_model()
model.summary()
# Out:
# Model: "MLP_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_13 (Dense)            (None, 64)                512
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dense_15 (Dense)            (None, 1)                 65
#
# ...
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
history =model.fit(X_train,y_train,validation_data = (X_test,y_test),epochs = 300)
# EPOCHS = 500
# # Store training stats
# history = model.fit(X_train,y_train, epochs=EPOCHS,
#                     validation_split=0.2, verbose=1)
# Out:
# Epoch 1/300
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0227 - accuracy: 0.9930 - val_loss: 0.4369 - val_accuracy: 0.6947
# Epoch 2/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 0.9947 - val_loss: 0.4573 - val_accuracy: 0.7000
# Epoch 3/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 0.9947 - val_loss: 0.4207 - val_accuracy: 0.6737
# Epoch 4/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9947 - val_loss: 0.4446 - val_accuracy: 0.6632
# Epoch 5/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0295 - accuracy: 0.9912 - val_loss: 0.4447 - val_accuracy: 0.6737
# Epoch 6/300
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0320 - accuracy: 0.9859 - val_loss: 0.4398 - val_accuracy: 0.6789
# Epoch 7/300
# ...

# %%
n_timesteps = X_train.shape[0]

# %%
n_timesteps
# Out:
# 568

# %%
n_features  = X_train.shape[1]

# %%
n_features
# Out:
# 7

# %%
#Rshape the data
# That is, each sample has 13 time steps with 1 input dimension. You can also think as each sample has 13 rows 1 column!

# %%
# Model 3:
def build_conv1D_model():

  n_timesteps = X_train.shape[0] #568
  n_features  = X_train.shape[1] #7 
  model = tf.keras.models.Sequential(name="model_conv1D")
  model.add(tf.keras.layers.Input(shape=(n_timesteps,n_features)))
  model.add(tf.keras.layers.Conv1D(filters=64, kernel_size=7, activation='relu', name="Conv1D_1"))

  model.add(tf.keras.layers.Dropout(0.5))
  model.add(tf.keras.layers.Conv1D(filters=32, kernel_size=3, activation='custom_activation', name="Conv1D_2"))
  # 
      # tf.keras.layers.Dense(21,activation='custom_activation'),
      #  tf.keras.layers.Dense(21,activation='gelu'),
  #
  model.add(tf.keras.layers.Conv1D(filters=16, kernel_size=2, activation='relu', name="Conv1D_3"))
  model.add(tf.keras.layers.Conv1D(filters=16, kernel_size=2, activation='custom_activation', name="Conv1D_4"))
  model.add(tf.keras.layers.Conv1D(filters=16, kernel_size=2, activation='custom_activation', name="Conv1D_5"))
  model.add(tf.keras.layers.Conv1D(filters=16, kernel_size=2, activation='custom_activation', name="Conv1D_6"))
  model.add(tf.keras.layers.Conv1D(filters=16, kernel_size=2, activation='custom_activation', name="Conv1D_7"))
  model.add(tf.keras.layers.MaxPooling1D(pool_size=2, name="MaxPooling1D"))
  model.add(tf.keras.layers.Flatten())
  model.add(tf.keras.layers.Dense(32, activation='relu', name="Dense_1"))
  model.add(tf.keras.layers.Dense(n_features, name="Dense_2"))


  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss=tf.keras.losses.MeanSquaredError(),
                optimizer='adam',
                metrics=['accuracy'])
  return model

model_conv1D = build_conv1D_model()
model_conv1D.summary()
# Out:
# Model: "model_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Conv1D_1 (Conv1D)           (None, 562, 64)           3200
#
#  dropout_3 (Dropout)         (None, 562, 64)           0
#
#  Conv1D_2 (Conv1D)           (None, 560, 32)           6176
#
#  Conv1D_3 (Conv1D)           (None, 559, 16)           1040
#
#  Conv1D_4 (Conv1D)           (None, 558, 16)           528
#
#  Conv1D_5 (Conv1D)           (None, 557, 16)           528
#
#  Conv1D_6 (Conv1D)           (None, 556, 16)           528
#
#  Conv1D_7 (Conv1D)           (None, 555, 16)           528
#
#  MaxPooling1D (MaxPooling1D)  (None, 277, 16)          0
#
#  flatten_3 (Flatten)         (None, 4432)              0
#
#  Dense_1 (Dense)             (None, 32)                141856
#
#  Dense_2 (Dense)             (None, 7)                 231
#
# ...
# Total params: 154,615
# Trainable params: 154,615
# Non-trainable params: 0
# ...

# %%
history =model.fit(X_train,y_train,validation_data = (X_test,y_test),epochs = 500)
# Out:
# Epoch 1/500
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0207 - accuracy: 0.9965 - val_loss: 0.4549 - val_accuracy: 0.6632
# Epoch 2/500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9947 - val_loss: 0.4659 - val_accuracy: 0.6684
# Epoch 3/500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9965 - val_loss: 0.4329 - val_accuracy: 0.7053
# Epoch 4/500
# 18/18 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9982 - val_loss: 0.4504 - val_accuracy: 0.6895
# Epoch 5/500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.4430 - val_accuracy: 0.6947
# Epoch 6/500
# 18/18 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.4693 - val_accuracy: 0.6789
# Epoch 7/500
# ...

# %%
model.save('my_model.h5')

# %%
import matplotlib.pyplot as plt
def plot_history(history):
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [1000$]')
  plt.plot(history.epoch, np.array(history.history['accuracy']), 
           label='Train')
  plt.plot(history.epoch, np.array(history.history['val_accuracy']),
           label = 'Val')
  plt.legend()
  plt.ylim([0,max(history.history['val_accuracy'])])

# %%
plot_history(history)

# %%
# filename = 'finalized_model.sav'
# import pickle
# pickle.dump(model, open(filename, 'wb'))
 
# # load the model from disk
# loaded_model = pickle.load(open(filename, 'rb'))

# %%
results
# Out:
#                        Models  Accuracy  Precision  Recall     F1
# 0                  GaussianNB     0.716      0.597   0.561  0.578
# 1          LogisticRegression     0.753      0.667   0.576  0.618
# 2      DecisionTreeClassifier     0.753      0.661   0.591  0.624
# 3                         SVC     0.763      0.678   0.606  0.640
# 4  GradientBoostingClassifier     0.753      0.651   0.621  0.636
# 5        KNeighborsClassifier     0.689      0.600   0.318  0.416

# %%
2*(0.7804*0.8196) / (0.7804 + 0.8196)

# %%
dict_acc = {'Models':['Neural_net, KMeans'],
            'Accuracy':[0.9349,35.552],'Precision': [0.8196, 0.509],'Recall':0.7804,'F1':0.7995 }
results = results.append(dict_acc,ignore_index=True)

# %%
results

# %%
def conf_matrix(model):
  from sklearn.metrics import confusion_matrix
  predict_label = model.predict(X_test)
#predict_label = np.argmax(predict_label,axis=1)
  return confusion_matrix(predict_label,y_test)

def plot_confmat(conf_matrix):
  plt.figure(figsize = (5,5))
  sns.heatmap(conf_matrix/np.sum(conf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
  plt.show()

# %%
conf_matrix(model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-0a45568e44ee> in <module>
# ----> 1 conf_matrix(model)
#
# <ipython-input-91-aaf0f0f96352> in conf_matrix(model)
#       3   predict_label = model.predict(X_test)
#       4 #predict_label = np.argmax(predict_label,axis=1)
# ----> 5   return confusion_matrix(predict_label,y_test)
#       6
#       7 def plot_confmat(conf_matrix):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# ...

# %%
for models in classifiers:
  plot_confmat(conf_matrix(models))

# %%
from sklearn.metrics import confusion_matrix
predict_label = model.predict(X_test)
predict_label = np.argmax(predict_label,axis=1)
confmat =  confusion_matrix(predict_label,y_test)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
confmat = np.array([[124,  10],[  12,   15]])

# %%
plot_confmat(confmat)

# %%
# import numpy as np
# fig,ax1 = plt.subplots()

# plt.rcParams["figure.figsize"] = (20,30)
# fig.suptitle('Model Comparison', fontsize=16, fontweight='bold')
# fig.set_figheight(7)
# fig.set_figwidth(14)
# fig.set_facecolor('white')

# # First plot
# ## set bar size
# barWidth = 0.1
# Gaussian_score = [results['Accuracy'][0],results['Precision'][0],results['Recall'][0],results['F1'][0]]
# LR_score = [results['Accuracy'][1],results['Precision'][1],results['Recall'][1],results['F1'][1]]
# DTC_score = [results['Accuracy'][2],results['Precision'][2],results['Recall'][2],results['F1'][2]]
# SVC_score = [results['Accuracy'][3],results['Precision'][3],results['Recall'][3],results['F1'][3]]
# XGB_score = [results['Accuracy'][4],results['Precision'][4],results['Recall'][4],results['F1'][4]]
# KNN_score = [results['Accuracy'][5],results['Precision'][5],results['Recall'][5],results['F1'][5]]
# NN_score = [results['Accuracy'][6],results['Precision'][6],results['Recall'][6],results['F1'][6]]
# KMeans_score = [.35,results1['Precision'][0],results1['Recall'][0],results1['F1'][0]] 

# ## Set position of bar on X axis
# r1 = np.arange(len(Gaussian_score))
# r2 = [x + barWidth for x in r1]
# r3 = [x + barWidth for x in r2]
# r4 = [x + barWidth for x in r3]
# r5 = [x + barWidth for x in r4]
# r6 = [x + barWidth for x in r5]
# r7 = [x + barWidth for x in r6]
# r8 = [x + barWidth for x in r7]

# ## Make the plot
# ax1.bar(r1, Gaussian_score, width=barWidth, edgecolor='white', label='Gaussian')
# ax1.bar(r2, LR_score, width=barWidth, edgecolor='white', label='Logistic Regression')
# ax1.bar(r3, DTC_score, width=barWidth, edgecolor='white', label='Decision Tree')
# ax1.bar(r4, SVC_score, width=barWidth, edgecolor='white', label='SVC')
# ax1.bar(r5, XGB_score, width=barWidth, edgecolor='white', label='XG Boost')
# ax1.bar(r6, KNN_score, width=barWidth, edgecolor='white', label='KNN')
# ax1.bar(r7, NN_score, width=barWidth, edgecolor='white', label='Neural Network')
# ax1.bar(r8, KMeans_score, width=barWidth, edgecolor='white', label='KMeans')


# ## Configure x and y axis
# ax1.set_xlabel('Metrics', fontweight='bold')
# labels = ['Accuracy', 'Precision', 'Recall', 'F1', 'Kappa']
# ax1.set_xticks([r + (barWidth * 1.5) for r in range(len(Gaussian_score))], )
# ax1.set_xticklabels(labels)
# ax1.set_ylabel('Score', fontweight='bold')
# ax1.set_ylim(0, 1)
# for p in ax1.patches:
#     ax1.annotate(format(p.get_height()*100, '.0f'), 
#                    (p.get_x() + p.get_width() / 2., p.get_height()), 
#                    ha = 'center', va = 'center', 
#                    xytext = (0, 10), 
#                    textcoords = 'offset points')
# ## Create legend & title
# ax1.set_title('Evaluation Metrics', fontsize=14, fontweight='bold')
# ax1.legend()
# plt.show()

# %%
# Gaussian_score = results['Accuracy'][0]*100
# LR_score = results['Accuracy'][1]*100
# DTC_score = results['Accuracy'][2]*100
# SVC_score = results['Accuracy'][3]*100
# NN_score = results['Accuracy'][4]*100
# result = {'Models': ['GaussianNB','Logistic Regression','Descision Tree','SVC','Nueral Network'], 
#                'Accuracy':[Gaussian_score, LR_score, DTC_score, SVC_score, NN_score]}
# resultsDF = pd.DataFrame.from_dict(results)

# from matplotlib.pyplot import figure
# figure(figsize=(8, 5), dpi=100)
# ax = sns.barplot(x = result['Models'],y = result['Accuracy'])
# widthbars = [0.4,0.3,0.3,0.3,0.3]
# for bar, newwidth in zip(ax.patches, widthbars):
#     x = bar.get_x()
#     width = bar.get_width()
#     centre = x + width/2.
#     bar.set_x(centre - newwidth/2.)
#     bar.set_width(newwidth)

# for p in ax.patches:
#     ax.annotate(format(p.get_height(), '.1f'), 
#                    (p.get_x() + p.get_width() / 2., p.get_height()), 
#                    ha = 'center', va = 'center', 
#                    xytext = (0, 9), 
#                    textcoords = 'offset points')

# plt.title("Model Comparision")
# plt.xlabel('Accuracy')
# plt.show()

# %%
#Sachin
